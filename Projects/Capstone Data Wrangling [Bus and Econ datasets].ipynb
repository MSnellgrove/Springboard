# %% [markdown]
# # Cleaning and Merging Business and Economy Datasets
#
# In this notebook we read in both the business and economy datasets. We follow the steps shown in this notebook: https://www.kaggle.com/code/shaumilsahariya/making-clean-data-from-business-and-economy-files
# with a few exceptions.
#
# 1) We keep the date column in yyyy-mm-dd format.
#
# 2) We keep the departure times and arrival times as time values instead of creating categories.
#
# 3) We keep 'stops' as numeric values.
#
# Then we compare this dataframe, called 'new', with the dataframe, called 'clean_dataset' using datacompy. We find that there are 108 rows in 'new' that are not in 'clean_dataset'. These rows are stored in the dataframe called 'missing_rows'.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import re
import datacompy

# %% [markdown]
# ## Read in csv files

# %%
business = pd.read_csv('./Data/archive/business.csv')
economy = pd.read_csv('./Data/archive/economy.csv')

# %%
business
# Out:
#              date    airline ch_code  num_code dep_time     from time_taken  \
# 0      11-02-2022  Air India      AI       868    18:00    Delhi    02h 00m
# 1      11-02-2022  Air India      AI       624    19:00    Delhi    02h 15m
# 2      11-02-2022  Air India      AI       531    20:00    Delhi    24h 45m
# 3      11-02-2022  Air India      AI       839    21:25    Delhi    26h 30m
# 4      11-02-2022  Air India      AI       544    17:15    Delhi    06h 40m
# ...           ...        ...     ...       ...      ...      ...        ...
# 93482  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
# 93483  31-03-2022    Vistara      UK       826    12:30  Chennai    10h 25m
# 93484  31-03-2022    Vistara      UK       832    07:05  Chennai    13h 50m
# 93485  31-03-2022    Vistara      UK       828    07:00  Chennai    10h 00m
# 93486  31-03-2022    Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                     stop arr_time         to  \
# 0                                              non-stop     20:00     Mumbai
# 1                                              non-stop     21:15     Mumbai
# 2      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:45     Mumbai
# 3      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# 4      1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    23:55     Mumbai
# ...                                                  ...      ...        ...
# 93482  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 93483  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 93484  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 93485  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 93486  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#         price
# 0      25,612
# 1      25,612
# 2      42,220
# 3      44,450
# 4      46,690
# ...       ...
# 93482  69,265
# 93483  77,105
# 93484  79,099
# 93485  81,585
# 93486  81,585
#
# [93487 rows x 11 columns]

# %%
economy
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 206769  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206770  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 206771  31-03-2022   Vistara      UK       826    12:30  Chennai    20h 35m
# 206772  31-03-2022   Vistara      UK       822    09:45  Chennai    23h 20m
# 206773  31-03-2022   Vistara      UK       824    20:30  Chennai    24h 25m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     21:05     Mumbai
# 1                                               non-stop     08:40     Mumbai
# 2                                               non-stop     06:35     Mumbai
# 3                                               non-stop     12:35     Mumbai
# 4                                               non-stop     11:10     Mumbai
# ...                                                   ...      ...        ...
# 206769  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206770  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 206771  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206772  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    09:05  Hyderabad
# 206773  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
#
#         price
# 0       5,953
# 1       5,953
# 2       5,956
# 3       5,955
# 4       5,955
# ...       ...
# 206769  7,697
# 206770  7,709
# 206771  8,640
# 206772  8,640
# 206773  8,640
#
# [206774 rows x 11 columns]

# %% [markdown]
# ## Adding in Class column in each dataframe

# %%
business["class"] = "business" 
economy["class"] = "economy"

# %% [markdown]
# ## Concatenating the two dataframes
#
# New DataFrame called 'new'.

# %%
new = pd.concat([economy, business],ignore_index = True)
new
# Out:
#               date   airline ch_code  num_code dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet      SG      8709    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet      SG      8157    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia      I5       764    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara      UK       995    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara      UK       963    08:50    Delhi    02h 20m
# ...            ...       ...     ...       ...      ...      ...        ...
# 300256  31-03-2022   Vistara      UK       822    09:45  Chennai    10h 05m
# 300257  31-03-2022   Vistara      UK       826    12:30  Chennai    10h 25m
# 300258  31-03-2022   Vistara      UK       832    07:05  Chennai    13h 50m
# 300259  31-03-2022   Vistara      UK       828    07:00  Chennai    10h 00m
# 300260  31-03-2022   Vistara      UK       822    09:45  Chennai    10h 05m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     21:05     Mumbai
# 1                                               non-stop     08:40     Mumbai
# 2                                               non-stop     06:35     Mumbai
# 3                                               non-stop     12:35     Mumbai
# 4                                               non-stop     11:10     Mumbai
# ...                                                   ...      ...        ...
# 300256  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 300257  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 300258  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 300259  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 300260  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#          price     class
# 0        5,953   economy
# 1        5,953   economy
# 2        5,956   economy
# 3        5,955   economy
# 4        5,955   economy
# ...        ...       ...
# 300256  69,265  business
# 300257  77,105  business
# 300258  79,099  business
# 300259  81,585  business
# 300260  81,585  business
#
# [300261 rows x 12 columns]

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        300261 non-null  object
#  1   airline     300261 non-null  object
#  2   ch_code     300261 non-null  object
#  3   num_code    300261 non-null  int64
#  4   dep_time    300261 non-null  object
#  5   from        300261 non-null  object
#  6   time_taken  300261 non-null  object
#  7   stop        300261 non-null  object
#  8   arr_time    300261 non-null  object
#  9   to          300261 non-null  object
#  10  price       300261 non-null  object
#  11  class       300261 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 27.5+ MB

# %% [markdown]
# ## Creating 'flight' column
#
# Merging 'ch_code' and 'num_code' and dropping 'ch_code' and 'num_code' columns.

# %%
new.num_code = new.num_code.astype("str")
new["flight"] = new["ch_code"] +"-"+ new["num_code"]
new.drop(["ch_code","num_code"],axis = 1,inplace = True)

# %%
new
# Out:
#               date   airline dep_time     from time_taken  \
# 0       11-02-2022  SpiceJet    18:55    Delhi    02h 10m
# 1       11-02-2022  SpiceJet    06:20    Delhi    02h 20m
# 2       11-02-2022   AirAsia    04:25    Delhi    02h 10m
# 3       11-02-2022   Vistara    10:20    Delhi    02h 15m
# 4       11-02-2022   Vistara    08:50    Delhi    02h 20m
# ...            ...       ...      ...      ...        ...
# 300256  31-03-2022   Vistara    09:45  Chennai    10h 05m
# 300257  31-03-2022   Vistara    12:30  Chennai    10h 25m
# 300258  31-03-2022   Vistara    07:05  Chennai    13h 50m
# 300259  31-03-2022   Vistara    07:00  Chennai    10h 00m
# 300260  31-03-2022   Vistara    09:45  Chennai    10h 05m
#
#                                                      stop arr_time         to  \
# 0                                               non-stop     21:05     Mumbai
# 1                                               non-stop     08:40     Mumbai
# 2                                               non-stop     06:35     Mumbai
# 3                                               non-stop     12:35     Mumbai
# 4                                               non-stop     11:10     Mumbai
# ...                                                   ...      ...        ...
# 300256  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
# 300257  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    22:55  Hyderabad
# 300258  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    20:55  Hyderabad
# 300259  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    17:00  Hyderabad
# 300260  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...    19:50  Hyderabad
#
#          price     class   flight
# 0        5,953   economy  SG-8709
# 1        5,953   economy  SG-8157
# 2        5,956   economy   I5-764
# 3        5,955   economy   UK-995
# 4        5,955   economy   UK-963
# ...        ...       ...      ...
# 300256  69,265  business   UK-822
# 300257  77,105  business   UK-826
# 300258  79,099  business   UK-832
# 300259  81,585  business   UK-828
# 300260  81,585  business   UK-822
#
# [300261 rows x 11 columns]

# %% [markdown]
# ## Renaming features

# %%
new.rename({"dep_time": "departure_time", "from": "source_city", 
            "time_taken": "duration", "stop": "stops", "arr_time": "arrival_time",
           "to":"destination_city"}, axis = 1, inplace = True)

# %%
new
# Out:
#               date   airline departure_time source_city duration  \
# 0       11-02-2022  SpiceJet          18:55       Delhi  02h 10m
# 1       11-02-2022  SpiceJet          06:20       Delhi  02h 20m
# 2       11-02-2022   AirAsia          04:25       Delhi  02h 10m
# 3       11-02-2022   Vistara          10:20       Delhi  02h 15m
# 4       11-02-2022   Vistara          08:50       Delhi  02h 20m
# ...            ...       ...            ...         ...      ...
# 300256  31-03-2022   Vistara          09:45     Chennai  10h 05m
# 300257  31-03-2022   Vistara          12:30     Chennai  10h 25m
# 300258  31-03-2022   Vistara          07:05     Chennai  13h 50m
# 300259  31-03-2022   Vistara          07:00     Chennai  10h 00m
# 300260  31-03-2022   Vistara          09:45     Chennai  10h 05m
#
#                                                     stops arrival_time  \
# 0                                               non-stop         21:05
# 1                                               non-stop         08:40
# 2                                               non-stop         06:35
# 3                                               non-stop         12:35
# 4                                               non-stop         11:10
# ...                                                   ...          ...
# 300256  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        19:50
# 300257  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        22:55
# 300258  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        20:55
# 300259  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        17:00
# 300260  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        19:50
#
#        destination_city   price     class   flight
# 0                Mumbai   5,953   economy  SG-8709
# 1                Mumbai   5,953   economy  SG-8157
# 2                Mumbai   5,956   economy   I5-764
# 3                Mumbai   5,955   economy   UK-995
# 4                Mumbai   5,955   economy   UK-963
# ...                 ...     ...       ...      ...
# 300256        Hyderabad  69,265  business   UK-822
# 300257        Hyderabad  77,105  business   UK-826
# 300258        Hyderabad  79,099  business   UK-832
# 300259        Hyderabad  81,585  business   UK-828
# 300260        Hyderabad  81,585  business   UK-822
#
# [300261 rows x 11 columns]

# %% [markdown]
# ## Creating 'days_left' column

# %%
dd = pd.DataFrame(new["date"].str.split("-",expand = True).to_numpy().astype(int),columns = ["day","month","year"])
new["days_left"] = np.where(dd["month"] > 2, dd["day"] +18, np.where(dd["month"] == 2, dd["day"] -10, dd["day"]))
new
# Out:
#               date   airline departure_time source_city duration  \
# 0       11-02-2022  SpiceJet          18:55       Delhi  02h 10m
# 1       11-02-2022  SpiceJet          06:20       Delhi  02h 20m
# 2       11-02-2022   AirAsia          04:25       Delhi  02h 10m
# 3       11-02-2022   Vistara          10:20       Delhi  02h 15m
# 4       11-02-2022   Vistara          08:50       Delhi  02h 20m
# ...            ...       ...            ...         ...      ...
# 300256  31-03-2022   Vistara          09:45     Chennai  10h 05m
# 300257  31-03-2022   Vistara          12:30     Chennai  10h 25m
# 300258  31-03-2022   Vistara          07:05     Chennai  13h 50m
# 300259  31-03-2022   Vistara          07:00     Chennai  10h 00m
# 300260  31-03-2022   Vistara          09:45     Chennai  10h 05m
#
#                                                     stops arrival_time  \
# 0                                               non-stop         21:05
# 1                                               non-stop         08:40
# 2                                               non-stop         06:35
# 3                                               non-stop         12:35
# 4                                               non-stop         11:10
# ...                                                   ...          ...
# 300256  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        19:50
# 300257  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        22:55
# 300258  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        20:55
# 300259  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        17:00
# 300260  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...        19:50
#
#        destination_city   price     class   flight  days_left
# 0                Mumbai   5,953   economy  SG-8709          1
# 1                Mumbai   5,953   economy  SG-8157          1
# 2                Mumbai   5,956   economy   I5-764          1
# 3                Mumbai   5,955   economy   UK-995          1
# 4                Mumbai   5,955   economy   UK-963          1
# ...                 ...     ...       ...      ...        ...
# 300256        Hyderabad  69,265  business   UK-822         49
# 300257        Hyderabad  77,105  business   UK-826         49
# 300258        Hyderabad  79,099  business   UK-832         49
# 300259        Hyderabad  81,585  business   UK-828         49
# 300260        Hyderabad  81,585  business   UK-822         49
#
# [300261 rows x 12 columns]

# %% [markdown]
# ## Checking Data Types
#
# Changing 'date' to a datetime64[ns] and 'departure_time' and 'arrival_time' to time.

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              300261 non-null  object
#  1   airline           300261 non-null  object
#  2   departure_time    300261 non-null  object
#  3   source_city       300261 non-null  object
#  4   duration          300261 non-null  object
#  5   stops             300261 non-null  object
#  6   arrival_time      300261 non-null  object
#  7   destination_city  300261 non-null  object
#  8   price             300261 non-null  object
#  9   class             300261 non-null  object
#  10  flight            300261 non-null  object
#  11  days_left         300261 non-null  int64
# dtypes: int64(1), object(11)
# memory usage: 27.5+ MB

# %%
new['date'] = pd.to_datetime(new['date'], format = '%d-%m-%Y')

# %%
new['departure_time'] = pd.to_datetime(new['departure_time'], format = '%H:%M').dt.time
new['arrival_time'] = pd.to_datetime(new['arrival_time'], format = '%H:%M').dt.time

# %%
new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   date              300261 non-null  datetime64[ns]
#  1   airline           300261 non-null  object
#  2   departure_time    300261 non-null  object
#  3   source_city       300261 non-null  object
#  4   duration          300261 non-null  object
#  5   stops             300261 non-null  object
#  6   arrival_time      300261 non-null  object
#  7   destination_city  300261 non-null  object
#  8   price             300261 non-null  object
#  9   class             300261 non-null  object
#  10  flight            300261 non-null  object
#  11  days_left         300261 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 27.5+ MB

# %%
new
# Out:
#              date   airline departure_time source_city duration  \
# 0      2022-02-11  SpiceJet       18:55:00       Delhi  02h 10m
# 1      2022-02-11  SpiceJet       06:20:00       Delhi  02h 20m
# 2      2022-02-11   AirAsia       04:25:00       Delhi  02h 10m
# 3      2022-02-11   Vistara       10:20:00       Delhi  02h 15m
# 4      2022-02-11   Vistara       08:50:00       Delhi  02h 20m
# ...           ...       ...            ...         ...      ...
# 300256 2022-03-31   Vistara       09:45:00     Chennai  10h 05m
# 300257 2022-03-31   Vistara       12:30:00     Chennai  10h 25m
# 300258 2022-03-31   Vistara       07:05:00     Chennai  13h 50m
# 300259 2022-03-31   Vistara       07:00:00     Chennai  10h 00m
# 300260 2022-03-31   Vistara       09:45:00     Chennai  10h 05m
#
#                                                     stops arrival_time  \
# 0                                               non-stop      21:05:00
# 1                                               non-stop      08:40:00
# 2                                               non-stop      06:35:00
# 3                                               non-stop      12:35:00
# 4                                               non-stop      11:10:00
# ...                                                   ...          ...
# 300256  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...     19:50:00
# 300257  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...     22:55:00
# 300258  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...     20:55:00
# 300259  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...     17:00:00
# 300260  1-stop\n\t\t\t\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t\t...     19:50:00
#
#        destination_city   price     class   flight  days_left
# 0                Mumbai   5,953   economy  SG-8709          1
# 1                Mumbai   5,953   economy  SG-8157          1
# 2                Mumbai   5,956   economy   I5-764          1
# 3                Mumbai   5,955   economy   UK-995          1
# 4                Mumbai   5,955   economy   UK-963          1
# ...                 ...     ...       ...      ...        ...
# 300256        Hyderabad  69,265  business   UK-822         49
# 300257        Hyderabad  77,105  business   UK-826         49
# 300258        Hyderabad  79,099  business   UK-832         49
# 300259        Hyderabad  81,585  business   UK-828         49
# 300260        Hyderabad  81,585  business   UK-822         49
#
# [300261 rows x 12 columns]

# %% [markdown]
# ### Question
#
# I see where the data type for 'date' was changed, but the datatypes for 'departure_time' and 'arrival_time' still say object. Is this an error?
#
# The format of the times is different, but not the data type.

# %% [markdown]
# ## Making 'duration' a float measured in hours only

# %%
temp = pd.DataFrame(new["duration"].str.split(expand = True).to_numpy().astype(str), 
                    columns = ["hour","minute"])
temp["hour"] = temp["hour"].apply(lambda x: re.sub("[^0-9]","",x)).astype(int)
temp["minute"] = temp["minute"].apply(lambda r: re.sub("[^0-9]","",r)) # we has no values in minute colum some where 
temp["minute"] = np.where(temp["minute"] == "", 0, temp["minute"]) # replaceing "" with 0
temp["minute"] = temp["minute"].astype(int) #converting data type
temp
# Out:
#         hour  minute
# 0          2      10
# 1          2      20
# 2          2      10
# 3          2      15
# 4          2      20
# ...      ...     ...
# 300256    10       5
# 300257    10      25
# 300258    13      50
# 300259    10       0
# 300260    10       5
#
# [300261 rows x 2 columns]

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300261 entries, 0 to 300260
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   hour    300261 non-null  int64
#  1   minute  300261 non-null  int64
# dtypes: int64(2)
# memory usage: 4.6 MB

# %%
temp['hour'].unique()
# Out:
# array([  2,  12,  16,  11,  14,  15,   3,   5,   8,   6,  18,  23,  24,
#          4,  19,  22,  26,  17,  20,  21,   7,  10,  28,   9,  13,  29,
#         27,  30,  25,  31,  33,  36,  35,  34,  39,   1,  37,  40,  32,
#         41,  38, 103, 102,   0,  47, 101,  42,  49,  45,  44])

# %%
temp['minute'].unique()
# Out:
# array([10, 20, 15,  5, 45, 30, 40, 50,  0, 25, 35, 55,  4, 59, 24])

# %% [markdown]
# ### Question
#
# The original data had values 1.01, 1.02, and 1.03 in the 'duration' column. The code above, strips out everything that isn't a digit, including the decimal point. These values are now showing up as 101, 102, and 103.
#
# I looked into the exact duration values those numbers came from, and they were entered as "1.03h m". Was that supposed to be interpretted as 61.8 minutes?
#
# Also, a lot of the duration hour times are pretty large for in-country flights...
#
# I feel like you said to split duration into hours and minutes and keep both as separate columns. Is that correct? In that case, 'duration' needs to be treated differently... couldn't remember what you said. I wasn't sure if I should do that before we compare with the other dataframe 'Clean_Dataset'.

# %% [markdown]
# ## Changing 'duration' column in 'new'

# %%
new["duration"] = np.around((temp["hour"] + (temp["minute"]/60)),2) #savin the total hours in duration feature
new.head()
# Out:
#         date   airline departure_time source_city  duration      stops  \
# 0 2022-02-11  SpiceJet       18:55:00       Delhi      2.17  non-stop
# 1 2022-02-11  SpiceJet       06:20:00       Delhi      2.33  non-stop
# 2 2022-02-11   AirAsia       04:25:00       Delhi      2.17  non-stop
# 3 2022-02-11   Vistara       10:20:00       Delhi      2.25  non-stop
# 4 2022-02-11   Vistara       08:50:00       Delhi      2.33  non-stop
#
#   arrival_time destination_city  price    class   flight  days_left
# 0     21:05:00           Mumbai  5,953  economy  SG-8709          1
# 1     08:40:00           Mumbai  5,953  economy  SG-8157          1
# 2     06:35:00           Mumbai  5,956  economy   I5-764          1
# 3     12:35:00           Mumbai  5,955  economy   UK-995          1
# 4     11:10:00           Mumbai  5,955  economy   UK-963          1

# %% [markdown]
# ## Changing 'stops' column to digits only and integer

# %%
new["stops"] = new["stops"].apply(lambda r: re.sub("[^0-9]","",r)) # taking only digits
new["stops"] = np.where(new["stops"] == "", 0, new["stops"]) # replacign "" with 0
new["stops"] = new["stops"].astype(int) # changing object to int
new.head()
# Out:
#         date   airline departure_time source_city  duration  stops  \
# 0 2022-02-11  SpiceJet       18:55:00       Delhi      2.17      0
# 1 2022-02-11  SpiceJet       06:20:00       Delhi      2.33      0
# 2 2022-02-11   AirAsia       04:25:00       Delhi      2.17      0
# 3 2022-02-11   Vistara       10:20:00       Delhi      2.25      0
# 4 2022-02-11   Vistara       08:50:00       Delhi      2.33      0
#
#   arrival_time destination_city  price    class   flight  days_left
# 0     21:05:00           Mumbai  5,953  economy  SG-8709          1
# 1     08:40:00           Mumbai  5,953  economy  SG-8157          1
# 2     06:35:00           Mumbai  5,956  economy   I5-764          1
# 3     12:35:00           Mumbai  5,955  economy   UK-995          1
# 4     11:10:00           Mumbai  5,955  economy   UK-963          1

# %% [markdown]
# ## Changing 'price' to digits only and integer

# %%
new["price"] = new["price"].apply(lambda r: re.sub("[^0-9]","",r)) # taking only digits
new["price"] = new["price"].astype(int) # changing object to int
new.head()
# Out:
#         date   airline departure_time source_city  duration  stops  \
# 0 2022-02-11  SpiceJet       18:55:00       Delhi      2.17      0
# 1 2022-02-11  SpiceJet       06:20:00       Delhi      2.33      0
# 2 2022-02-11   AirAsia       04:25:00       Delhi      2.17      0
# 3 2022-02-11   Vistara       10:20:00       Delhi      2.25      0
# 4 2022-02-11   Vistara       08:50:00       Delhi      2.33      0
#
#   arrival_time destination_city  price    class   flight  days_left
# 0     21:05:00           Mumbai   5953  economy  SG-8709          1
# 1     08:40:00           Mumbai   5953  economy  SG-8157          1
# 2     06:35:00           Mumbai   5956  economy   I5-764          1
# 3     12:35:00           Mumbai   5955  economy   UK-995          1
# 4     11:10:00           Mumbai   5955  economy   UK-963          1

# %% [markdown]
# ## Reordering the columns

# %%
new = new[["date","airline","flight","source_city","departure_time","stops",
     "arrival_time","destination_city","class","duration","days_left","price"]]

# %%
new
# Out:
#              date   airline   flight source_city departure_time  stops  \
# 0      2022-02-11  SpiceJet  SG-8709       Delhi       18:55:00      0
# 1      2022-02-11  SpiceJet  SG-8157       Delhi       06:20:00      0
# 2      2022-02-11   AirAsia   I5-764       Delhi       04:25:00      0
# 3      2022-02-11   Vistara   UK-995       Delhi       10:20:00      0
# 4      2022-02-11   Vistara   UK-963       Delhi       08:50:00      0
# ...           ...       ...      ...         ...            ...    ...
# 300256 2022-03-31   Vistara   UK-822     Chennai       09:45:00      1
# 300257 2022-03-31   Vistara   UK-826     Chennai       12:30:00      1
# 300258 2022-03-31   Vistara   UK-832     Chennai       07:05:00      1
# 300259 2022-03-31   Vistara   UK-828     Chennai       07:00:00      1
# 300260 2022-03-31   Vistara   UK-822     Chennai       09:45:00      1
#
#        arrival_time destination_city     class  duration  days_left  price
# 0          21:05:00           Mumbai   economy      2.17          1   5953
# 1          08:40:00           Mumbai   economy      2.33          1   5953
# 2          06:35:00           Mumbai   economy      2.17          1   5956
# 3          12:35:00           Mumbai   economy      2.25          1   5955
# 4          11:10:00           Mumbai   economy      2.33          1   5955
# ...             ...              ...       ...       ...        ...    ...
# 300256     19:50:00        Hyderabad  business     10.08         49  69265
# 300257     22:55:00        Hyderabad  business     10.42         49  77105
# 300258     20:55:00        Hyderabad  business     13.83         49  79099
# 300259     17:00:00        Hyderabad  business     10.00         49  81585
# 300260     19:50:00        Hyderabad  business     10.08         49  81585
#
# [300261 rows x 12 columns]

# %%
new.hist(figsize = (15, 10))
plt.subplots_adjust(hspace = 0.5);

# %% [markdown]
# ## Read in 'clean_dataset' and compare with 'new'

# %%
clean_dataset = pd.read_csv('./Clean_Dataset.csv')

# %%
clean_dataset
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# 0               Night           Mumbai   Economy      2.17          1   5953
# 1             Morning           Mumbai   Economy      2.33          1   5953
# 2       Early_Morning           Mumbai   Economy      2.17          1   5956
# 3           Afternoon           Mumbai   Economy      2.25          1   5955
# 4             Morning           Mumbai   Economy      2.33          1   5955
# ...               ...              ...       ...       ...        ...    ...
# 300148        Evening        Hyderabad  Business     10.08         49  69265
# 300149          Night        Hyderabad  Business     10.42         49  77105
# 300150          Night        Hyderabad  Business     13.83         49  79099
# 300151        Evening        Hyderabad  Business     10.00         49  81585
# 300152        Evening        Hyderabad  Business     10.08         49  81585
#
# [300153 rows x 12 columns]

# %%
new.describe()
# Out:
#                stops       duration      days_left          price
# count  300261.000000  300261.000000  300261.000000  300261.000000
# mean        0.924213      12.219142      26.004473   20883.717666
# std         0.398188       7.200348      13.560985   22695.911266
# min         0.000000       0.830000       1.000000    1105.000000
# 25%         1.000000       6.750000      15.000000    4783.000000
# 50%         1.000000      11.250000      26.000000    7425.000000
# 75%         1.000000      16.170000      38.000000   42521.000000
# max         2.000000     103.000000      49.000000  123071.000000

# %%
clean_dataset.drop(columns = 'Unnamed: 0', inplace = True)

# %%
clean_dataset.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %% [markdown]
# ### Differences
#
# The counts differ by 108.
#
# Max value for 'duration' in 'new' is 103 (as expected). The max 'duration in 'clean_dataset' is 49.83.
#
# Next, I sort_values in both dataframes by 'duration' to see if there are any other durations between 49.83 and 101.

# %%
print(new.sort_values('duration', ascending = False). head())
# Out:
#              date    airline  flight source_city departure_time  stops  \
# 111315 2022-02-26   GO FIRST  G8-146   Bangalore       05:45:00      2
# 96486  2022-02-26   GO FIRST  G8-146   Bangalore       05:45:00      1
# 104676 2022-02-26   GO FIRST  G8-146   Bangalore       05:45:00      2
# 154007 2022-02-25   GO FIRST  G8-517   Hyderabad       20:45:00      1
# 193997 2022-02-12  Air India  AI-672     Chennai       16:05:00      2
#
#        arrival_time destination_city    class  duration  days_left  price
# 111315     09:30:00        Hyderabad  economy    103.00         16   4337
# 96486      09:10:00           Mumbai  economy    103.00         16   5177
# 104676     08:00:00          Kolkata  economy    102.00         16   5177
# 154007     21:50:00            Delhi  economy    101.00         15   6132
# 193997     17:55:00        Bangalore  economy     49.83          2  23891

# %%
print(clean_dataset.sort_values('duration', ascending = False).head())
# Out:
#           airline  flight source_city departure_time        stops  \
# 194359  Air_India  AI-672     Chennai        Evening          one
# 193889  Air_India  AI-672     Chennai        Evening  two_or_more
# 261152  Air_India  AI-610   Bangalore        Evening          one
# 119508  Air_India  AI-610   Bangalore        Evening          one
# 193926    Vistara  UK-822     Chennai        Morning          one
#
#        arrival_time destination_city     class  duration  days_left  price
# 194359      Evening        Bangalore   Economy     49.83          9  17538
# 193889      Evening        Bangalore   Economy     49.83          2  23891
# 261152      Evening          Chennai  Business     47.75         47  55122
# 119508      Evening          Chennai   Economy     47.75         47   7461
# 193926      Morning        Bangalore   Economy     47.08          3  17223

# %% [markdown]
# ## Comparing 'new' and 'clean_dataset' using datacompy

# %%
compare = datacompy.Compare(new, clean_dataset, join_columns = ['duration', 'price'])
print(compare.report())
# Out:
# /Users/morgansnellgrove/opt/anaconda3/lib/python3.9/site-packages/datacompy/core.py:258: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df1[order_column] = generate_id_within_group(
# DataComPy Comparison
# --------------------
#
# DataFrame Summary
# -----------------
#
#   DataFrame  Columns    Rows
# 0       df1       12  300261
# 1       df2       11  300153
#
# Column Summary
# --------------
#
# Number of columns in common: 11
# Number of columns in df1 but not in df2: 1
# Number of columns in df2 but not in df1: 0
#
# Row Summary
# -----------
#
# Matched on: duration, price
# Any duplicates on match values: Yes
# Absolute Tolerance: 0
# Relative Tolerance: 0
# Number of rows in common: 300,153
# Number of rows in df1 but not in df2: 108
# Number of rows in df2 but not in df1: 0
#
# Number of rows with some compared columns unequal: 300,153
# Number of rows with all compared columns equal: 0
#
# Column Comparison
# -----------------
#
# Number of columns compared with some values unequal: 7
# Number of columns compared with all values equal: 4
# Total number of values which compare unequal: 1,304,696
#
# Columns with Unequal Values or Types
# ------------------------------------
#
#            Column df1 dtype df2 dtype  # Unequal  Max Diff  # Null Diff
# 0         airline    object    object     104065       0.0            0
# 4    arrival_time    object    object     300153       0.0            0
# 5           class    object    object     300153       0.0            0
# 6       days_left     int64     int64         15       9.0            0
# 2  departure_time    object    object     300153       0.0            0
# 1          flight    object    object          4       0.0            0
# 3           stops     int64    object     300153       0.0            0
#
# Sample Rows with Unequal Values
# -------------------------------
#
#         duration  price airline (df1) airline (df2)
# 296722      9.25  55377     Air India     Air_India
# 175922     16.75   5209     Air India     Air_India
# 202512     16.92   4287     Air India     Air_India
# 142206     14.25   6109      GO FIRST      GO_FIRST
# 25450      11.92   7790      GO FIRST      GO_FIRST
# 200380     26.17   4363     Air India     Air_India
# 13326      26.42   6148     Air India     Air_India
# 247187      8.08  45435     Air India     Air_India
# 87232       7.75   3466      GO FIRST      GO_FIRST
# 95123      18.58  11545     Air India     Air_India
#
#         duration  price flight (df1) flight (df2)
# 110789       1.0   4337       S5-151       G8-510
# 109730       1.0   4337       S5-151       G8-510
# 110430       1.0   4337       S5-151       G8-510
# 110001       1.0   4337       S5-151       G8-510
#
#         duration  price departure_time (df1) departure_time (df2)
# 188704      9.58   8980             09:00:00              Morning
# 292045     15.08  69713             06:55:00        Early_Morning
# 9749        9.17   6296             14:15:00            Afternoon
# 282701     17.17  63277             17:40:00              Evening
# 67875       9.33   6252             22:40:00                Night
# 206168     17.42   3979             06:10:00        Early_Morning
# 155584     27.25   4172             06:00:00        Early_Morning
# 217300     18.17  65529             15:30:00            Afternoon
# 189534      2.08   4832             22:15:00                Night
# 238139     14.42  50810             21:30:00                Night
#
#         duration  price  stops (df1) stops (df2)
# 8724       19.25   6339            1         one
# 124175     10.33   8089            1         one
# 178034     11.25   6287            1         one
# 271732     10.67  67497            1         one
# 262353     16.08  68303            1         one
# 165645      9.67   4451            1         one
# 193199     24.25   4357            1         one
# 82776       7.00   4663            1         one
# 90678       4.75   3811            1         one
# 28168      24.83   4933            1         one
#
#         duration  price arrival_time (df1) arrival_time (df2)
# 145875     26.33  10139           12:35:00          Afternoon
# 284970      9.83  74981           22:45:00              Night
# 283860     15.92  66234           09:35:00            Morning
# 155270      5.58   2228           01:20:00         Late_Night
# 168140      7.83   5136           18:45:00            Evening
# 185358     17.42   3916           23:45:00              Night
# 279906     10.42  58315           23:50:00              Night
# 36902       9.58  11625           19:55:00            Evening
# 47257       5.33   5985           23:55:00              Night
# 258948     13.17  56588           22:55:00              Night
#
#         duration  price class (df1) class (df2)
# 20355       2.33   5954     economy     Economy
# 71987      12.25   7584     economy     Economy
# 145073     31.75   6055     economy     Economy
# 275512     12.08  54115    business    Business
# 198990      8.75  12918     economy     Economy
# 197772     22.08   4755     economy     Economy
# 97154      21.00   6578     economy     Economy
# 288358      5.58  57920    business    Business
# 278042     13.33  45883    business    Business
# 206554      9.17   1105     economy     Economy
#
#         duration  price  days_left (df1)  days_left (df2)
# 110789      1.00   4337               12             15.0
# 110430      1.00   4337                9             13.0
# 110675      1.00   4337               11             14.0
# 6315       24.58   4780               32             36.0
# 110001      1.00   4337                5             12.0
# 696        15.25  12150                5              6.0
# 109730      1.00   4337                2             11.0
# 6181       24.58   4780               31             32.0
# 1052       15.25  12150                7              8.0
# 873        15.25  12150                6              7.0
#
# Sample Rows Only in df1 (First 10 Columns)
# ------------------------------------------
#
#              date   airline  flight source_city departure_time  stops arrival_time destination_city    class  duration
# 114866 2022-03-26   StarAir  S5-151   Bangalore       07:05:00      0     08:05:00        Hyderabad  economy      1.00
# 111315 2022-02-26  GO FIRST  G8-146   Bangalore       05:45:00      2     09:30:00        Hyderabad  economy    103.00
# 114608 2022-03-24   StarAir  S5-151   Bangalore       07:05:00      0     08:05:00        Hyderabad  economy      1.00
# 165647 2022-02-12    Trujet  2T-623   Hyderabad       08:35:00      1     11:00:00        Bangalore  economy      2.42
# 76056  2022-03-23    Trujet  2T-518      Mumbai       11:40:00      1     19:00:00        Hyderabad  economy      7.33
# 111025 2022-02-24   StarAir  S5-151   Bangalore       07:05:00      0     08:05:00        Hyderabad  economy      1.00
# 165847 2022-02-15   StarAir  S5-152   Hyderabad       20:20:00      0     21:25:00        Bangalore  economy      1.08
# 168555 2022-03-12    Trujet  2T-623   Hyderabad       08:35:00      1     11:00:00        Bangalore  economy      2.42
# 167756 2022-03-05    Trujet  2T-623   Hyderabad       08:35:00      1     11:00:00        Bangalore  economy      2.42
# 166222 2022-02-19    Trujet  2T-623   Hyderabad       08:35:00      1     11:00:00        Bangalore  economy      2.42

# %% [markdown]
# ## Creating DataFrame of rows missing from 'clean_dataset'

# %%
missing_rows = compare.df1_unq_rows

# %%
missing_rows
# Out:
#              date    airline  flight source_city departure_time  stops  \
# 2036   2022-02-22  Air India  AI-807       Delhi       17:20:00      1
# 7816   2022-03-21  Air India  AI-475       Delhi       13:00:00      1
# 71637  2022-02-22     Trujet  2T-518      Mumbai       11:40:00      1
# 73768  2022-03-08     Trujet  2T-518      Mumbai       11:40:00      1
# 73920  2022-03-09     Trujet  2T-518      Mumbai       11:40:00      1
# ...           ...        ...     ...         ...            ...    ...
# 170021 2022-03-25     Trujet  2T-623   Hyderabad       08:35:00      1
# 170131 2022-03-26    StarAir  S5-152   Hyderabad       20:20:00      0
# 170139 2022-03-26     Trujet  2T-623   Hyderabad       08:35:00      1
# 170514 2022-03-29    StarAir  S5-152   Hyderabad       20:20:00      0
# 170754 2022-03-31    StarAir  S5-152   Hyderabad       20:20:00      0
#
#        arrival_time destination_city    class  duration  days_left  price
# 2036       08:35:00           Mumbai  economy     15.25         12  12150
# 7816       13:35:00           Mumbai  economy     24.58         39   4780
# 71637      19:00:00        Hyderabad  economy      7.33         12   3166
# 73768      19:00:00        Hyderabad  economy      7.33         26   3166
# 73920      19:00:00        Hyderabad  economy      7.33         27   3166
# ...             ...              ...      ...       ...        ...    ...
# 170021     11:00:00        Bangalore  economy      2.42         43   3196
# 170131     21:25:00        Bangalore  economy      1.08         44   2115
# 170139     11:00:00        Bangalore  economy      2.42         44   3196
# 170514     21:25:00        Bangalore  economy      1.08         47   2115
# 170754     21:25:00        Bangalore  economy      1.08         49   2115
#
# [108 rows x 12 columns]

# %%
missing_rows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 2036 to 170754
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              108 non-null    datetime64[ns]
#  1   airline           108 non-null    object
#  2   flight            108 non-null    object
#  3   source_city       108 non-null    object
#  4   departure_time    108 non-null    object
#  5   stops             108 non-null    int64
#  6   arrival_time      108 non-null    object
#  7   destination_city  108 non-null    object
#  8   class             108 non-null    object
#  9   duration          108 non-null    float64
#  10  days_left         108 non-null    int64
#  11  price             108 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(7)
# memory usage: 11.0+ KB

# %%
missing_rows.describe()
# Out:
#             stops    duration   days_left         price
# count  108.000000  108.000000  108.000000    108.000000
# mean     0.648148    6.997685   25.620370   4367.361111
# std      0.517268   19.025075   13.211237   2851.432873
# min      0.000000    1.000000    2.000000   2000.000000
# 25%      0.000000    1.080000   15.000000   2115.000000
# 50%      1.000000    2.420000   26.000000   3196.000000
# 75%      1.000000    5.080000   37.000000   4534.000000
# max      2.000000  103.000000   49.000000  17482.000000

# %%
missing_rows.hist(figsize = (15, 10))
plt.subplots_adjust(hspace = 0.5);

# %%
print(missing_rows.sort_values('price', ascending = False).head())
# Out:
#              date    airline  flight source_city departure_time  stops  \
# 110098 2022-02-15    StarAir  S5-131   Bangalore       14:35:00      1
# 2036   2022-02-22  Air India  AI-807       Delhi       17:20:00      1
# 109764 2022-02-12    StarAir  S5-131   Bangalore       14:35:00      1
# 112272 2022-03-05    StarAir  S5-131   Bangalore       14:35:00      1
# 169988 2022-03-24    StarAir  S5-150   Hyderabad       08:35:00      1
#
#        arrival_time destination_city    class  duration  days_left  price
# 110098     19:40:00        Hyderabad  economy      5.08          5  17482
# 2036       08:35:00           Mumbai  economy     15.25         12  12150
# 109764     19:40:00        Hyderabad  economy      5.08          2  11382
# 112272     19:40:00        Hyderabad  economy      5.08         23   9682
# 169988     13:40:00        Bangalore  economy      5.08         42   9582

# %%
missing_rows['class'].unique()
# Out:
# array(['economy'], dtype=object)

# %% [markdown]
# ## Thoughts
#
# 'Missing_rows' does contain the 4 really high duration values.
#
# The price distribution shows one value really far to the right. When I sort 'missing_rows' by price, that expensive flight was economy, but the ticket was bought only 5 days before departure. This could explain the expensive ticket.
#
# It's odd that all of the rows that were dropped from 'clean_dataset' were economy flights. No business flights were dropped.
#
# Nothing is standing out to me that explains why these rows were dropped from 'clean_dataset'. I'm thinking we should fix the duration values and keep the missing rows.
